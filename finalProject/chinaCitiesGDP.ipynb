# %% [markdown]
# this notebook retrieves the population of each city in China

# %%
import pandas as pd
import numpy as np
#lets import whatever is required
import requests
import lxml.html as lh

# %%
# lets now retrieve all of the table cells from the page
url = "https://theslittyeye.wordpress.com/2018/03/26/2017-top-50-chinese-cities-gdp-nominal-per-capita-raw-data-compiling/"
page = requests.get(url)
# store the content of the website under doc
doc = lh.fromstring(page.content)
#parse data that are stored between <tr>..<tr>
tr_elements = doc.xpath('//tr')

# %%
# as you see we are only interested on those rows which have 4 columns
# therefore I will creat a new list out of elements with the length of 9
elements4 = [T for T in tr_elements if len(T)==7]
i = 0 
# the first element with length of 4 is the columns heading
# note that we are only interested on province, capital and the population
col = ['City','GDPpc(USD)']
GDPpc = pd.DataFrame(columns = col)
GDPpc
# Out:
# Empty DataFrame
# Columns: [City, GDPpc(USD)]
# Index: []

# %%
# now lets fill it
numel = 0;
for t in elements4[1:]:
    numel+=1
    GDPpc = GDPpc.append({
        'City':t[0].text_content().split('\n')[0]
        ,'GDPpc(USD)':t[6].text_content().split('\n')[0]  
    },ignore_index=True)
    
GDPpc
# Out:
#               City GDPpc(USD)
# 0            Erdos      37125
# 1         Shenzhen      32351
# 2         Dongying      31782
# 3             Wuxi      25469
# 4           Suzhou      25257
# 5        Guangzhou      24230
# 6          Nanjing      22414
# 7        Changzhou      22239
# 8         Hangzhou      21618
# 9         Changsha      21097
# 10         Qingdao      20452
# 11         Beijing      20407
# 12          Ningbo      19778
# 13        Shanghai      19718
# 14           Wuhan      19687
# 15         Tianjin      19019
# 16          Foshan      17768
# 17          Yantai      17042
# 18          Xiamen      17009
# 19         Nantong      16798
# 20        Shaoxing      16773
# 21            Zibo      16662
# 22          Dalian      16643
# 23           Jinan      16327
# 24        Yangzhou      16025
# 25          Fuzhou      14899
# 26         Taizhou      14776
# 27        Nanchang      14733
# 28        Dongguan      14415
# 29       Zhengzhou      14231
# 30        Quanzhou      14006
# 31         Chengdu      13805
# 32           Hefei      12143
# 33            Xian      12066
# 34          Xuzhou      11990
# 35       Changchun      11890
# 36         Taizhou      11514
# 37        Shenyang      11204
# 38        Yancheng      11037
# 39        Tangshan      10835
# 40         Weifang      10796
# 41         Kunming      10583
# 42         Luoyang      10106
# 43          Harbin       9838
# 44  Shijiangzhuang       9626
# 45         Wenzhou       9444
# 46       Chongqing       9164
# 47          Jining       9047
# 48         Nanning       8795
# 49           Linxi       6585

# %%
GDPpc.to_csv('GDPpc.csv',index=False)
